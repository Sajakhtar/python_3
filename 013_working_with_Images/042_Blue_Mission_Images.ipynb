# %% [markdown]
# # Blue Mission Overview
#
# Looks like the email reply had two links:
#
# https://drive.google.com/file/d/15YyLqIuGlsCLr4ioKUeHRw8H2QjBNOz2/view
#
# https://drive.google.com/file/d/128MRLNuytoW7dVm6B7AF_cDVMeACyTFk/view
#
# See if you can figure out how to use these images to figure out the next step.
#
# Best of luck!

# %% [markdown]
# #### File Names
#
# image_link.png
# cover_image.png
#
# image_link.jpg
# cover_image.jpg

# %%
from PIL import Image

# %%
image_link = Image.open('image_link.png')

# %%
cover_image = Image.open('cover_image.png')

# %%
image_link.size
# Out:
# (1226, 777)

# %%
cover_image.size
# Out:
# (1093, 693)

# %%
cover_image = cover_image.resize(image_link.size)

# %%
cover_image.size
# Out:
# (1226, 777)

# %%
image_link
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1226x777 at 0x24142F83408>

# %%
cover_image
# Out:
# <PIL.Image.Image image mode=RGBA size=1226x777 at 0x2414300A088>

# %%
cover_image.putalpha(100)

# %%
image_link.paste(im=cover_image, box=(0,0), mask=cover_image)

# %%
image_link
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1226x777 at 0x24142F83408>

# %% [markdown]
# Result link is:
#
# https://goo.gl/LDo5Nt
