# %% [markdown]
# # Opening and Reading Files
#
# So far we've discussed how to open files manually, one by one. Let's explore how we can open files programatically.

# %% [markdown]
# ### Create Practice File
#
# We will begin by creating a practice text file that we will be using for demonstration.

# %%
f = open('practice.txt', 'w+') # in write mode

# %%
f.write("test line")
# Out:
# 9

# %% [markdown]
# ### Getting Directories
#
# Python has a built-in [os module](https://docs.python.org/3/library/os.html) that allows us to use operating system dependent functionality.
#
# You can get the current directory:

# %%
f.close()

# %%
import os

# %%
os.getcwd() # current working directory
# Out:
# 'C:\\Users\\Sajakhta\\Desktop\\Complete_Python3_Masterclass'

# %%
os.listdir() # list files in current directory
# Out:
# ['.ipynb_checkpoints',
#  '000_example.py',
#  '001_example_notebook.ipynb',
#  '002_Numbers.ipynb',
#  '003_Strings.ipynb',
#  '004_Lists.ipynb',
#  '005_Dictionaries.ipynb',
#  '006_Tuples.ipynb',
#  '007_Sets.ipynb',
#  '008_Booleans.ipynb',
#  '009_Working_with_files.ipynb',
#  '010_Field_Readiness_Exam_One.ipynb',
#  '011_Control_FLow.ipynb',
#  '012_While_loops.ipynb',
#  '013_For_loops.ipynb',
#  '014_Useful_operators.ipynb',
#  '015_List_Comprehensions.ipynb',
#  '016_Field_Readiness_Exam_Two .ipynb',
#  '017_Functions.ipynb',
#  '018_Function_Tasks.ipynb',
#  '019_Nested_Statements_and_Scope.ipynb',
#  '020_Lambda_Expressions_Map_Filter.ipynb',
#  '021_Hacking_Incident.ipynb',
#  '022_OOP.ipynb',
#  '023_OOP_Exercise.ipynb',
#  '024_Errors_Handling_Exceptions.ipynb',
#  '025_Debugging_Datetime.ipynb',
#  '026_myprogram.py',
#  '027_Name_Main.ipynb',
#  '028_Field_Readiness_Final_Test.ipynb',
#  '029_Web_Scraping.ipynb',
#  '030_RED_Mission_Web_Scraping.ipynb',
#  '031_RegEx.ipynb',
#  '032_Opening_Reading_Files.ipynb',
#  'cicada_image_new.jpg',
#  'exam.txt',
#  'mission',
#  'mymodule.py',
#  'one.py',
#  'original.zip',
#  'practice.txt',
#  'Python-Narrative-Journey-master',
#  'second_file.txt',
#  'testfile',
#  'testfile2',
#  'testfile3',
#  'test_file.txt',
#  'third_file.txt',
#  'two.py',
#  'unzip_me_for_instructions.zip',
#  '__pycache__']

# %%
os.listdir('C:\\Users') # pass in any directory path
# Out:
# ['adm-matienza1',
#  'ADMINI~1',
#  'All Users',
#  'Default',
#  'Default User',
#  'desktop.ini',
#  'Public',
#  'Sajakhta']

# %% [markdown]
# ### Moving Files
#
# You can use the built-in **shutil** module to to move files to different locations. Keep in mind, there are permission restrictions, for example if you are logged in a User A, you won't be able to make changes to the top level Users folder without the proper permissions, [more info](https://stackoverflow.com/questions/23253439/shutil-movescr-dst-gets-me-ioerror-errno-13-permission-denied-and-3-more-e)
#
# Utilities for working with files e.g. zipping, unzipping, moving files

# %%
import shutil

# %%
# move practice file to desktop
shutil.move('practice.txt', 'C:\\Users\\Sajakhta\\Desktop') # (source, destination)
#reports back final location of the file
# Out:
# 'C:\\Users\\Sajakhta\\Desktop\\practice.txt'

# %%
os.listdir('C:\\Users\\Sajakhta\\Desktop') # check file was moved
# Out:
# ['003_Completed Data Registry',
#  'Advanced ADH Query Writing Training.pdf',
#  'Astrolabs Bootcamp',
#  'Azure',
#  'c',
#  'Cisco Webex Meetings.lnk',
#  'ClientDisclosureLetter_ADH_Expo 2020_Legal_8-3-2020.docx',
#  'ClientDisclosureLetter_ADH_Publicis Media MENA_Consolidated_with responses (v2).docx',
#  'ClientDisclosureLetter_ADH_Publicis Media MENA_Umniah_tracked.docx',
#  'ClientDisclosureLetter_ADH_Publicis Media MENA_YMC_tracked.docx',
#  'Complete_Python3_Masterclass',
#  'Complete_UiPath_RPA_Developer_Course',
#  'countdown',
#  'desktop.ini',
#  'desktop.pptx',
#  'Jamovi',
#  'LinkedIn background image.pptx',
#  'Node Projects',
#  'Optispect Template.xlsx',
#  'Plotly_Dash',
#  'practice.txt',
#  'Publicis CoE ADH Training.pdf',
#  'Sajid (SSO) - Chrome.lnk',
#  'Sajid - Chrome.lnk',
#  'Sundog_Education_Hadoop',
#  'Trafficking Scripts',
#  'Udemy_RPA_Bryan Lamb',
#  'Wes Bos JS 30x30']

# %%
# move file back to current directory
shutil.move('C:\\Users\\Sajakhta\\Desktop\\practice.txt', os.getcwd())
# Out:
# 'C:\\Users\\Sajakhta\\Desktop\\Complete_Python3_Masterclass\\practice.txt'

# %%
os.listdir() # check file was moved
# Out:
# ['.ipynb_checkpoints',
#  '000_example.py',
#  '001_example_notebook.ipynb',
#  '002_Numbers.ipynb',
#  '003_Strings.ipynb',
#  '004_Lists.ipynb',
#  '005_Dictionaries.ipynb',
#  '006_Tuples.ipynb',
#  '007_Sets.ipynb',
#  '008_Booleans.ipynb',
#  '009_Working_with_files.ipynb',
#  '010_Field_Readiness_Exam_One.ipynb',
#  '011_Control_FLow.ipynb',
#  '012_While_loops.ipynb',
#  '013_For_loops.ipynb',
#  '014_Useful_operators.ipynb',
#  '015_List_Comprehensions.ipynb',
#  '016_Field_Readiness_Exam_Two .ipynb',
#  '017_Functions.ipynb',
#  '018_Function_Tasks.ipynb',
#  '019_Nested_Statements_and_Scope.ipynb',
#  '020_Lambda_Expressions_Map_Filter.ipynb',
#  '021_Hacking_Incident.ipynb',
#  '022_OOP.ipynb',
#  '023_OOP_Exercise.ipynb',
#  '024_Errors_Handling_Exceptions.ipynb',
#  '025_Debugging_Datetime.ipynb',
#  '026_myprogram.py',
#  '027_Name_Main.ipynb',
#  '028_Field_Readiness_Final_Test.ipynb',
#  '029_Web_Scraping.ipynb',
#  '030_RED_Mission_Web_Scraping.ipynb',
#  '031_RegEx.ipynb',
#  '032_Opening_Reading_Files.ipynb',
#  'cicada_image_new.jpg',
#  'exam.txt',
#  'mission',
#  'mymodule.py',
#  'one.py',
#  'original.zip',
#  'practice.txt',
#  'Python-Narrative-Journey-master',
#  'second_file.txt',
#  'testfile',
#  'testfile2',
#  'testfile3',
#  'test_file.txt',
#  'third_file.txt',
#  'two.py',
#  'unzip_me_for_instructions.zip',
#  '__pycache__']

# %% [markdown]
# ### Deleting Files
# ____
# **NOTE: The os module provides 3 methods for deleting files:**
# * os.unlink(path) which deletes a file at the path your provide
# * os.rmdir(path) which deletes a folder (folder must be empty) at the path your provide
# * shutil.rmtree(path) this is the most dangerous, as it will remove all files and folders contained in the path.
# **All of these methods can not be reversed! Which means if you make a mistake you won't be able to recover the file. Instead we will use the send2trash module. A safer alternative that sends deleted files to the trash bin instead of permanent removal.**
# ___
#
# Install the send2trash module with:
#
#     pip install send2trash
#
# at your command line.

# %%
#path = 'C:\\Users\\Sajakhta\\Desktop\\Complete_Python3_Masterclass\\practice.txt'

# %%
'''
os.unlink(path) # deletes files at path provided
os.rmdir(path) # delete direcory folder, folder must be empty
shutil.rmtree(path) # Remove all files/folder contained in the path, so most dangerous
# These are dangerous and can't be reveresed
'''
# Out:
# "\nos.unlink(path) # deletes files at path provided\nos.rmdir(path) # delete direcory folder, folder must be empty\nshutil.rmtree(path) # Remove all files/folder contained in the path, so most dangerous\n# These are dangerous and can't be reveresed\n"

# %%
# install from command line in notebook using !

# %%
# !pip install send2trash
# Out:
# Requirement already satisfied: send2trash in c:\users\sajakhta\appdata\local\continuum\anaconda3\lib\site-packages (1.5.0)

# %%
# send2trash is safer, sends to Recycle bin to be able to recover files
import send2trash

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '000_example.py',
#  '001_example_notebook.ipynb',
#  '002_Numbers.ipynb',
#  '003_Strings.ipynb',
#  '004_Lists.ipynb',
#  '005_Dictionaries.ipynb',
#  '006_Tuples.ipynb',
#  '007_Sets.ipynb',
#  '008_Booleans.ipynb',
#  '009_Working_with_files.ipynb',
#  '010_Field_Readiness_Exam_One.ipynb',
#  '011_Control_FLow.ipynb',
#  '012_While_loops.ipynb',
#  '013_For_loops.ipynb',
#  '014_Useful_operators.ipynb',
#  '015_List_Comprehensions.ipynb',
#  '016_Field_Readiness_Exam_Two .ipynb',
#  '017_Functions.ipynb',
#  '018_Function_Tasks.ipynb',
#  '019_Nested_Statements_and_Scope.ipynb',
#  '020_Lambda_Expressions_Map_Filter.ipynb',
#  '021_Hacking_Incident.ipynb',
#  '022_OOP.ipynb',
#  '023_OOP_Exercise.ipynb',
#  '024_Errors_Handling_Exceptions.ipynb',
#  '025_Debugging_Datetime.ipynb',
#  '026_myprogram.py',
#  '027_Name_Main.ipynb',
#  '028_Field_Readiness_Final_Test.ipynb',
#  '029_Web_Scraping.ipynb',
#  '030_RED_Mission_Web_Scraping.ipynb',
#  '031_RegEx.ipynb',
#  '032_Opening_Reading_Files.ipynb',
#  'cicada_image_new.jpg',
#  'exam.txt',
#  'mission',
#  'mymodule.py',
#  'one.py',
#  'original.zip',
#  'practice.txt',
#  'Python-Narrative-Journey-master',
#  'second_file.txt',
#  'testfile',
#  'testfile2',
#  'testfile3',
#  'test_file.txt',
#  'third_file.txt',
#  'two.py',
#  'unzip_me_for_instructions.zip',
#  '__pycache__']

# %%
send2trash.send2trash('practice.txt')

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '000_example.py',
#  '001_example_notebook.ipynb',
#  '002_Numbers.ipynb',
#  '003_Strings.ipynb',
#  '004_Lists.ipynb',
#  '005_Dictionaries.ipynb',
#  '006_Tuples.ipynb',
#  '007_Sets.ipynb',
#  '008_Booleans.ipynb',
#  '009_Working_with_files.ipynb',
#  '010_Field_Readiness_Exam_One.ipynb',
#  '011_Control_FLow.ipynb',
#  '012_While_loops.ipynb',
#  '013_For_loops.ipynb',
#  '014_Useful_operators.ipynb',
#  '015_List_Comprehensions.ipynb',
#  '016_Field_Readiness_Exam_Two .ipynb',
#  '017_Functions.ipynb',
#  '018_Function_Tasks.ipynb',
#  '019_Nested_Statements_and_Scope.ipynb',
#  '020_Lambda_Expressions_Map_Filter.ipynb',
#  '021_Hacking_Incident.ipynb',
#  '022_OOP.ipynb',
#  '023_OOP_Exercise.ipynb',
#  '024_Errors_Handling_Exceptions.ipynb',
#  '025_Debugging_Datetime.ipynb',
#  '026_myprogram.py',
#  '027_Name_Main.ipynb',
#  '028_Field_Readiness_Final_Test.ipynb',
#  '029_Web_Scraping.ipynb',
#  '030_RED_Mission_Web_Scraping.ipynb',
#  '031_RegEx.ipynb',
#  '032_Opening_Reading_Files.ipynb',
#  'cicada_image_new.jpg',
#  'exam.txt',
#  'mission',
#  'mymodule.py',
#  'one.py',
#  'original.zip',
#  'Python-Narrative-Journey-master',
#  'second_file.txt',
#  'testfile',
#  'testfile2',
#  'testfile3',
#  'test_file.txt',
#  'third_file.txt',
#  'two.py',
#  'unzip_me_for_instructions.zip',
#  '__pycache__']

# %% [markdown]
# ### Walking through a directory
#
# Often you will just need to "walk" through a directory, that is visit every file or folder and check to see if a file is in the directory, and then perhaps do something with that file. Usually recursively walking through every file and folder in a directory would be quite tricky to program, but luckily the os module has a direct method call for this called os.walk(). Let's explore how it works.

# %%
my_path = os.getcwd()

# %%
my_path
# Out:
# 'C:\\Users\\Sajakhta\\Desktop\\Complete_Python3_Masterclass'

# %%
# tuple unpacking
for folder, sub_folders, files in os.walk(my_path):
    print("Currently looking at folder: {}".format(folder))
    
    print('\n')
    
    print("Sub-folders here are: ")
    
    for sub_folder in sub_folders:
        print("\t" + sub_folder)
    
    print('\n')
    
    print("files here are: ")
    
    for f in files:
        print("\t" + f)
        # open(f, 'w+') # here you can open file and write to it 
    print('\n')
# Out:
# Currently looking at folder: C:\Users\Sajakhta\Desktop\Complete_Python3_Masterclass
#
#
# Sub-folders here are:
# 	.ipynb_checkpoints
# 	mission
# 	Python-Narrative-Journey-master
# 	__pycache__
#
#
# files here are:
# 	000_example.py
# 	001_example_notebook.ipynb
# 	002_Numbers.ipynb
# 	003_Strings.ipynb
# 	004_Lists.ipynb
# 	005_Dictionaries.ipynb
# 	006_Tuples.ipynb
# 	007_Sets.ipynb
# 	008_Booleans.ipynb
# 	009_Working_with_files.ipynb
# 	010_Field_Readiness_Exam_One.ipynb
# 	011_Control_FLow.ipynb
# 	012_While_loops.ipynb
# 	013_For_loops.ipynb
# 	014_Useful_operators.ipynb
# 	015_List_Comprehensions.ipynb
# 	016_Field_Readiness_Exam_Two .ipynb
# 	017_Functions.ipynb
# 	018_Function_Tasks.ipynb
# 	019_Nested_Statements_and_Scope.ipynb
# 	020_Lambda_Expressions_Map_Filter.ipynb
# 	021_Hacking_Incident.ipynb
# 	022_OOP.ipynb
# 	023_OOP_Exercise.ipynb
# 	024_Errors_Handling_Exceptions.ipynb
# 	025_Debugging_Datetime.ipynb
# 	026_myprogram.py
# 	027_Name_Main.ipynb
# 	028_Field_Readiness_Final_Test.ipynb
# 	029_Web_Scraping.ipynb
# 	030_RED_Mission_Web_Scraping.ipynb
# 	031_RegEx.ipynb
# 	032_Opening_Reading_Files.ipynb
# 	cicada_image_new.jpg
# 	exam.txt
# 	mymodule.py
# 	one.py
# 	original.zip
# 	second_file.txt
# 	testfile
# 	testfile2
# 	testfile3
# 	test_file.txt
# 	third_file.txt
# 	two.py
# 	unzip_me_for_instructions.zip
#
#
# Currently looking at folder: C:\Users\Sajakhta\Desktop\Complete_Python3_Masterclass\.ipynb_checkpoints
#
#
# Sub-folders here are:
#
#
# files here are:
# 	001_example_notebook-checkpoint.ipynb
# 	002_Numbers-checkpoint.ipynb
# 	003_Strings-checkpoint.ipynb
# 	004_Lists-checkpoint.ipynb
# 	005_Dictionaries-checkpoint.ipynb
# 	006_Tuples-checkpoint.ipynb
# 	007_Sets-checkpoint.ipynb
# 	008_Booleans-checkpoint.ipynb
# 	009_Working_with_files-checkpoint.ipynb
# 	010_Field_Readiness_Exam_One-checkpoint.ipynb
# 	011_Control_FLow-checkpoint.ipynb
# 	012_While_loops-checkpoint.ipynb
# 	013_For_loops-checkpoint.ipynb
# 	014_Useful_operators-checkpoint.ipynb
# 	015_List_Comprehensions-checkpoint.ipynb
# 	016_Field_Readiness_Exam_Two -checkpoint.ipynb
# 	017_Functions-checkpoint.ipynb
# 	018_Function_Tasks-checkpoint.ipynb
# 	020_Lambda_Expressions_Map_Filter-checkpoint.ipynb
# 	021_Hacking_Incident-checkpoint.ipynb
# 	022_OOP-checkpoint.ipynb
# 	023_OOP_Exercise-checkpoint.ipynb
# 	024_Errors_Handling_Exceptions-checkpoint.ipynb
# 	025_Debugging_Datetime-checkpoint.ipynb
# 	027_Name_Main-checkpoint.ipynb
# 	028_Field_Readiness_Final_Test-checkpoint.ipynb
# 	029_Web_Scraping-checkpoint.ipynb
# 	030_RED_Mission_Web_Scraping-checkpoint.ipynb
# 	031_RegEx-checkpoint.ipynb
# 	032_Opening_Reading_Files-checkpoint.ipynb
#
#
# Currently looking at folder: C:\Users\Sajakhta\Desktop\Complete_Python3_Masterclass\mission
#
#
# Sub-folders here are:
# 	Five
# 	Four
# 	One
# 	Three
# 	Two
#
#
# files here are:
# 	Instructions.txt
#
#
# Currently looking at folder: C:\Users\Sajakhta\Desktop\Complete_Python3_Masterclass\mission\Five
#
#
# Sub-folders here are:
#
#
# files here are:
# 	AEITMYIRQLP.txt
# 	APJKSRITGGX.txt
# 	AQKATDFGXTS.txt
# 	ARLKFCWIAJE.txt
# 	AXJGVPVEFAS.txt
# 	BNUQEHCFRTG.txt
# 	BSKJDRNEZQM.txt
# 	BTYWAHLHKBM.txt
# 	BUGKBZWRRVI.txt
# 	BVBURZZCAPR.txt
# 	CAHBEVSVDDN.txt
# 	COMGMZBJAYE.txt
# 	CRFSDGYFSHA.txt
# 	CSCLFZCDYYC.txt
# 	CXBVCTRBBIE.txt
# 	DDLASODUVPX.txt
# 	DHZBAAYEADM.txt
# 	DQPZQLBCJYP.txt
# 	DYOPIIVMZOO.txt
# 	DZUWWXYIAEL.txt
# 	EAAOEPSAWMQ.txt
# 	EIPWXMQZJKU.txt
# 	ESIZWBHMGDP.txt
# 	ETCUEXWNBCF.txt
# 	EYTCGIOYWIW.txt
#
#
# Currently looking at folder: C:\Users\Sajakhta\Desktop\Complete_Python3_Masterclass\mission\Four
#
#
# Sub-folders here are:
#
#
# files here are:
# 	ECIOBYCDVFI.txt
# 	EMTGPSXQEJX.txt
# 	EPRNUHRSESC.txt
# 	ESDIZXHYCVY.txt
# 	EXVQSVBQQQH.txt
# 	QCTCKDIBBVG.txt
# 	QCWCFLKNZMN.txt
# 	QDDETWBHJYC.txt
# 	QTDYYIFPHAU.txt
# 	QVNJULGXNUM.txt
# 	REAXWSOIQDY.txt
# 	ROICPTWKXDX.txt
# 	RSXOTNGKBML.txt
# 	RXDARIDGKBF.txt
# 	RYNXFYXMKHG.txt
# 	TAKNAVDMZKV.txt
# 	THPNEGKTJWI.txt
# 	TJFMLJODVAD.txt
# 	TKCZSFQNJTX.txt
# 	TWUOYFCCYBQ.txt
# 	WFSKPTXPFCH.txt
# 	WHTOHQUWXIN.txt
# 	WNJISWPEBRS.txt
# 	WXDJDOGZEHN.txt
# 	WYDLGSGGXKV.txt
#
#
# Currently looking at folder: C:\Users\Sajakhta\Desktop\Complete_Python3_Masterclass\mission\One
#
#
# Sub-folders here are:
#
#
# files here are:
# 	HDOHZHFSTTK.txt
# 	HFUTPPAXDIS.txt
# 	HMNZTLIFGPD.txt
# 	HRQFTHKVJTL.txt
# 	HVUTZEVMSBW.txt
# 	JDLRVFCXYLU.txt
# 	JEHBLZPUPSP.txt
# 	JLTXKIGCWDL.txt
# 	JQUOBKFUACN.txt
# 	JTHSNBNPQSE.txt
# 	KCXGNQCZBLO.txt
# 	KFIUZFERLET.txt
# 	KMMLGJOWLGI.txt
# 	KNBSKDREHQU.txt
# 	KTXDHIOKAUI.txt
# 	LDGOCUQJNNS.txt
# 	LFEATJAAYDC.txt
# 	LHODFIKVTQA.txt
# 	LIFDHOFKWOI.txt
# 	LPNDVDXPZIG.txt
# 	PDJMSMNKIRM.txt
# 	PHWAVPEKAER.txt
# 	PLYCGPVEAWO.txt
# 	PQNVCVJINAR.txt
# 	PTOBBCJYURJ.txt
#
#
# Currently looking at folder: C:\Users\Sajakhta\Desktop\Complete_Python3_Masterclass\mission\Three
#
#
# Sub-folders here are:
#
#
# files here are:
# 	VAQIJTDOFUJ.txt
# 	VCFJCGJFBIH.txt
# 	VSXFSTABZDY.txt
# 	VVHFVZUNLOO.txt
# 	VVKGWLRMHLU.txt
# 	XAJMCPEWFNI.txt
# 	XFHJOTNPEJG.txt
# 	XHZPVUQTXIO.txt
# 	XJCWENFFGHB.txt
# 	XVMPVSVYKFR.txt
# 	YCESZHJDBXH.txt
# 	YDQFMWXOUMW.txt
# 	YQBIUHSUEVW.txt
# 	YQRNCMNFFHW.txt
# 	YYIZGBTQHZP.txt
# 	ZEZKKRBIZEB.txt
# 	ZKQJXAYKPVD.txt
# 	ZOWVXWPOGWP.txt
# 	ZXEZRQXZNPG.txt
# 	ZXIBJMPROKW.txt
#
#
# Currently looking at folder: C:\Users\Sajakhta\Desktop\Complete_Python3_Masterclass\mission\Two
#
#
# Sub-folders here are:
#
#
# files here are:
# 	GKQBQRCTNNK.txt
# 	GMMQQUBMJNR.txt
# 	GQTJJORZBXY.txt
# 	GTOTCIWMDBY.txt
# 	GXYSEPAFRTP.txt
# 	HARDNJGDRBC.txt
# 	HEORIXOTANT.txt
# 	HMUTDOVNYTV.txt
# 	HMZXPBOPRAE.txt
# 	HTOHSTYXTCO.txt
# 	LCJZYDHBFRM.txt
# 	LSQSTGPIGIY.txt
# 	LULTNYAQEJG.txt
# 	LVMBINRBJXL.txt
# 	LYZEQCVYNEZ.txt
# 	OHZOUOSFJQC.txt
# 	OIHMLGMWTHL.txt
# 	OKWFOOYTXFU.txt
# 	OMWIMVRCMYM.txt
# 	OYMAGXAGWHJ.txt
# 	SIKFPPLCJDN.txt
# 	SJMJLDGPBSJ.txt
# 	SOFUJYXTIMK.txt
# 	SPDZYGDHEWO.txt
# 	SWOFXREEHWA.txt
#
#
# Currently looking at folder: C:\Users\Sajakhta\Desktop\Complete_Python3_Masterclass\Python-Narrative-Journey-master
#
#
# Sub-folders here are:
# 	01-Recruitment-Trials-Bootcamp-Python-Basics
# 	02-Field-Readiness-Exam-1
# 	03-Recruitment-Trials-Bootcamp-Working-with-Python
# 	04-Field-Readiness-Exam-2
# 	05-Recruitment-Trials-Bootcamp-Part-3
# 	06-Hacking-Incident
# 	07-Final-Recruitment-Topics
# 	08-Final-Field-Readiness-Exam
# 	10-Red-Mission-Web-Scraping
# 	11-Orange-Mission-Regular-Expressions-and-Reading-Files
# 	12-Yellow-Mission-Working-with-CSV-Files
# 	13-Green-Mission-Sending-Emails-with-Python
# 	14-Blue-Mission-Working-with-Images-with-Python
# 	15-Indigo-Mission-Decryption-with-Python
# 	16-Violet-Mission-Mapping-with-Python
#
#
# files here are:
# 	README.md
#
#
# Currently looking at folder: C:\Users\Sajakhta\Desktop\Complete_Python3_Masterclass\Python-Narrative-Journey-master\01-Recruitment-Trials-Bootcamp-Python-Basics
#
#
# Sub-folders here are:
# 	.ipynb_checkpoints
#
#
# files here are:
# 	00-Python-Numbers.ipynb
# 	01-Python-Strings.ipynb
# 	02-Python-Lists.ipynb
# 	03-Python-Dictionaries.ipynb
# 	04-Tuples.ipynb
# 	05-Sets.ipynb
# 	06-Booleans.ipynb
# 	07-Working-with-Simple-Text-Files.ipynb
# 	second_file.txt
# 	test_file.txt
# 	totally_new_file.txt
#
#
# Currently looking at folder: C:\Users\Sajakhta\Desktop\Complete_Python3_Masterclass\Python-Narrative-Journey-master\01-Recruitment-Trials-Bootcamp-Python-Basics\.ipynb_checkpoints
#
#
# Sub-folders here are:
#
#
# files here are:
# 	00-Python-Numbers-checkpoint.ipynb
# 	01-Python-Strings-checkpoint.ipynb
# 	02-Python-Lists-checkpoint.ipynb
# 	03-Python-Dictionaries-checkpoint.ipynb
# 	04-Tuples-checkpoint.ipynb
# 	05-Sets-checkpoint.ipynb
# 	06-Booleans-checkpoint.ipynb
# 	07-Working-with-Simple-Text-Files-checkpoint.ipynb
#
#
# Currently looking at folder: C:\Users\Sajakhta\Desktop\Complete_Python3_Masterclass\Python-Narrative-Journey-master\02-Field-Readiness-Exam-1
#
#
# Sub-folders here are:
# 	.ipynb_checkpoints
#
#
# files here are:
# 	01-Field-Readiness-Exam-One.ipynb
# 	01-Field-Readiness-Exam-Solutions.ipynb
# 	exam.txt
#
#
# Currently looking at folder: C:\Users\Sajakhta\Desktop\Complete_Python3_Masterclass\Python-Narrative-Journey-master\02-Field-Readiness-Exam-1\.ipynb_checkpoints
#
#
# Sub-folders here are:
#
#
# files here are:
# 	01-Field-Readiness-Exam-One-checkpoint.ipynb
# 	01-Field-Readiness-Exam-Solutions-checkpoint.ipynb
#
#
# Currently looking at folder: C:\Users\Sajakhta\Desktop\Complete_Python3_Masterclass\Python-Narrative-Journey-master\03-Recruitment-Trials-Bootcamp-Working-with-Python
#
#
# Sub-folders here are:
# 	.ipynb_checkpoints
#
#
# files here are:
# 	00-Control-Flow-Basics-if-elif-else.ipynb
# 	01-While-Loops.ipynb
# 	02-For-Loops.ipynb
# 	03-Useful-Operators.ipynb
# 	04-List-Comprehensions.ipynb
#
#
# Currently looking at folder: C:\Users\Sajakhta\Desktop\Complete_Python3_Masterclass\Python-Narrative-Journey-master\03-Recruitment-Trials-Bootcamp-Working-with-Python\.ipynb_checkpoints
#
#
# Sub-folders here are:
#
#
# files here are:
# 	00-Control-Flow-Basics-if-elif-else-checkpoint.ipynb
# 	01-While-Loops-checkpoint.ipynb
# 	02-For-Loops-checkpoint.ipynb
# 	03-Useful-Operators-checkpoint.ipynb
# 	04-List-Comprehensions-checkpoint.ipynb
#
#
# Currently looking at folder: C:\Users\Sajakhta\Desktop\Complete_Python3_Masterclass\Python-Narrative-Journey-master\04-Field-Readiness-Exam-2
#
#
# Sub-folders here are:
# 	.ipynb_checkpoints
#
#
# files here are:
# 	00-Field-Readiness-Exam-II .ipynb
# 	01-Field-Readiness-Exam-II-Solutions.ipynb
#
#
# Currently looking at folder: C:\Users\Sajakhta\Desktop\Complete_Python3_Masterclass\Python-Narrative-Journey-master\04-Field-Readiness-Exam-2\.ipynb_checkpoints
#
#
# Sub-folders here are:
#
#
# files here are:
# 	00-Field-Readiness-Exam-II -checkpoint.ipynb
# 	01-Field-Readiness-Exam-II-Solutions-checkpoint.ipynb
#
#
# Currently looking at folder: C:\Users\Sajakhta\Desktop\Complete_Python3_Masterclass\Python-Narrative-Journey-master\05-Recruitment-Trials-Bootcamp-Part-3
#
#
# Sub-folders here are:
# 	.ipynb_checkpoints
#
#
# files here are:
# 	00-Functions.ipynb
# 	01-Function-Tasks.ipynb
# 	02-Function-Tasks-Solutions.ipynb
# 	03-Nested-Statements-and-Scope.ipynb
# 	04-Lambda-Expressions-Map-and-Filter.ipynb
#
#
# Currently looking at folder: C:\Users\Sajakhta\Desktop\Complete_Python3_Masterclass\Python-Narrative-Journey-master\05-Recruitment-Trials-Bootcamp-Part-3\.ipynb_checkpoints
#
#
# Sub-folders here are:
#
#
# files here are:
# 	00-Functions-checkpoint.ipynb
# 	01-Function-Tasks-checkpoint.ipynb
# 	02-Function-Tasks-Solutions-checkpoint.ipynb
# 	03-Nested-Statements-and-Scope-checkpoint.ipynb
# 	04-Lambda-Expressions-Map-and-Filter-checkpoint.ipynb
#
#
# Currently looking at folder: C:\Users\Sajakhta\Desktop\Complete_Python3_Masterclass\Python-Narrative-Journey-master\06-Hacking-Incident
#
#
# Sub-folders here are:
# 	.ipynb_checkpoints
#
#
# files here are:
# 	00-Hacking-Incident.ipynb
# 	01-Hacking-Incident-Debrief.ipynb
#
#
# Currently looking at folder: C:\Users\Sajakhta\Desktop\Complete_Python3_Masterclass\Python-Narrative-Journey-master\06-Hacking-Incident\.ipynb_checkpoints
#
#
# Sub-folders here are:
#
#
# files here are:
# 	00-Hacking-Incident-checkpoint.ipynb
# 	01-Hacking-Incident-Debrief-checkpoint.ipynb
#
#
# Currently looking at folder: C:\Users\Sajakhta\Desktop\Complete_Python3_Masterclass\Python-Narrative-Journey-master\07-Final-Recruitment-Topics
#
#
# Sub-folders here are:
# 	.ipynb_checkpoints
# 	05-Modules_and_Packages
# 	06-Name_and_Main
#
#
# files here are:
# 	00-Object-Oriented-Programming.ipynb
# 	01-Object-Oriented-Programming-Review-Exercise.ipynb
# 	02-Object-Oriented-Programming-Review-Exercise-Solutions.ipynb
# 	03-Error-Handling-and-Exceptions.ipynb
# 	04-Debugging-and-Datetime.ipynb
# 	Optional-Lecture-Decorators.ipynb
# 	Optional-Lecture-Generators.ipynb
# 	testfile
#
#
# Currently looking at folder: C:\Users\Sajakhta\Desktop\Complete_Python3_Masterclass\Python-Narrative-Journey-master\07-Final-Recruitment-Topics\.ipynb_checkpoints
#
#
# Sub-folders here are:
#
#
# files here are:
# 	00-Object-Oriented-Programming-checkpoint.ipynb
# 	01-Object-Oriented-Programming-Review-Exercise-checkpoint.ipynb
# 	02-Object-Oriented-Programming-Review-Exercise-Solutions-checkpoint.ipynb
# 	03-Error-Handling-and-Exceptions-checkpoint.ipynb
# 	04-Debugging-and-Datetime-checkpoint.ipynb
# 	Optional-Lecture-Decorators-checkpoint.ipynb
# 	Optional-Lecture-Generators-checkpoint.ipynb
#
#
# Currently looking at folder: C:\Users\Sajakhta\Desktop\Complete_Python3_Masterclass\Python-Narrative-Journey-master\07-Final-Recruitment-Topics\05-Modules_and_Packages
#
#
# Sub-folders here are:
#
#
# files here are:
# 	mymodule.py
# 	myprogram.py
#
#
# Currently looking at folder: C:\Users\Sajakhta\Desktop\Complete_Python3_Masterclass\Python-Narrative-Journey-master\07-Final-Recruitment-Topics\06-Name_and_Main
#
#
# Sub-folders here are:
#
#
# files here are:
# 	Explanation.txt
# 	one.py
# 	two.py
#
#
# Currently looking at folder: C:\Users\Sajakhta\Desktop\Complete_Python3_Masterclass\Python-Narrative-Journey-master\08-Final-Field-Readiness-Exam
#
#
# Sub-folders here are:
# 	.ipynb_checkpoints
#
#
# files here are:
# 	00-Field-Readiness-Final-Test.ipynb
# 	01-Field-Readiness-Final-Test-Solutions.ipynb
#
#
# Currently looking at folder: C:\Users\Sajakhta\Desktop\Complete_Python3_Masterclass\Python-Narrative-Journey-master\08-Final-Field-Readiness-Exam\.ipynb_checkpoints
#
#
# Sub-folders here are:
#
#
# files here are:
# 	00-Field-Readiness-Final-Test-checkpoint.ipynb
# 	01-Field-Readiness-Final-Test-Solutions-checkpoint.ipynb
#
#
# Currently looking at folder: C:\Users\Sajakhta\Desktop\Complete_Python3_Masterclass\Python-Narrative-Journey-master\10-Red-Mission-Web-Scraping
#
#
# Sub-folders here are:
# 	.ipynb_checkpoints
#
#
# files here are:
# 	00-Guide-to-Web-Scraping.ipynb
# 	01-RED-Mission-Overview.ipynb
# 	02-RED-Mission-Debrief.ipynb
# 	my_new_file_name.jpg
#
#
# Currently looking at folder: C:\Users\Sajakhta\Desktop\Complete_Python3_Masterclass\Python-Narrative-Journey-master\10-Red-Mission-Web-Scraping\.ipynb_checkpoints
#
#
# Sub-folders here are:
#
#
# files here are:
# 	00-Guide-to-Web-Scraping-checkpoint.ipynb
# 	01-RED-Mission-Overview-checkpoint.ipynb
# 	02-RED-Mission-Debrief-checkpoint.ipynb
#
#
# Currently looking at folder: C:\Users\Sajakhta\Desktop\Complete_Python3_Masterclass\Python-Narrative-Journey-master\11-Orange-Mission-Regular-Expressions-and-Reading-Files
#
#
# Sub-folders here are:
# 	.ipynb_checkpoints
# 	Example_Top_Level
# 	Mission_Orange_Files
#
#
# files here are:
# 	00-Overview-of-Regular-Expressions.ipynb
# 	01-Opening-and-Reading-Files.ipynb
# 	02-Unzipping-and-Zipping-Files.ipynb
# 	03-Orange-Mission.ipynb
# 	04-Orange-Mission-Debrief.ipynb
# 	comp_file.zip
# 	new_file.txt
# 	new_file2.txt
#
#
# Currently looking at folder: C:\Users\Sajakhta\Desktop\Complete_Python3_Masterclass\Python-Narrative-Journey-master\11-Orange-Mission-Regular-Expressions-and-Reading-Files\.ipynb_checkpoints
#
#
# Sub-folders here are:
#
#
# files here are:
# 	00-Overview-of-Regular-Expressions-checkpoint.ipynb
# 	01-Opening-and-Reading-Files-checkpoint.ipynb
# 	02-Unzipping-and-Zipping-Files-checkpoint.ipynb
# 	03-Orange-Mission-checkpoint.ipynb
# 	04-Orange-Mission-Debrief-checkpoint.ipynb
# 	Untitled-checkpoint.ipynb
#
#
# Currently looking at folder: C:\Users\Sajakhta\Desktop\Complete_Python3_Masterclass\Python-Narrative-Journey-master\11-Orange-Mission-Regular-Expressions-and-Reading-Files\Example_Top_Level
#
#
# Sub-folders here are:
# 	Mid-Example-One
#
#
# files here are:
# 	Mid-Example.txt
#
#
# Currently looking at folder: C:\Users\Sajakhta\Desktop\Complete_Python3_Masterclass\Python-Narrative-Journey-master\11-Orange-Mission-Regular-Expressions-and-Reading-Files\Example_Top_Level\Mid-Example-One
#
#
# Sub-folders here are:
# 	Bottom-Level-One
# 	Bottom-Level-Two
#
#
# files here are:
# 	Mid-Level-Doc.txt
#
#
# Currently looking at folder: C:\Users\Sajakhta\Desktop\Complete_Python3_Masterclass\Python-Narrative-Journey-master\11-Orange-Mission-Regular-Expressions-and-Reading-Files\Example_Top_Level\Mid-Example-One\Bottom-Level-One
#
#
# Sub-folders here are:
#
#
# files here are:
# 	One_Text.txt
#
#
# Currently looking at folder: C:\Users\Sajakhta\Desktop\Complete_Python3_Masterclass\Python-Narrative-Journey-master\11-Orange-Mission-Regular-Expressions-and-Reading-Files\Example_Top_Level\Mid-Example-One\Bottom-Level-Two
#
#
# Sub-folders here are:
#
#
# files here are:
# 	Bottom-Text-Two.txt
#
#
# Currently looking at folder: C:\Users\Sajakhta\Desktop\Complete_Python3_Masterclass\Python-Narrative-Journey-master\11-Orange-Mission-Regular-Expressions-and-Reading-Files\Mission_Orange_Files
#
#
# Sub-folders here are:
# 	extracted_content
#
#
# files here are:
# 	unzip_me_for_instructions.zip
#
#
# Currently looking at folder: C:\Users\Sajakhta\Desktop\Complete_Python3_Masterclass\Python-Narrative-Journey-master\11-Orange-Mission-Regular-Expressions-and-Reading-Files\Mission_Orange_Files\extracted_content
#
#
# Sub-folders here are:
# 	Five
# 	Four
# 	One
# 	Three
# 	Two
#
#
# files here are:
# 	Instructions.txt
#
#
# Currently looking at folder: C:\Users\Sajakhta\Desktop\Complete_Python3_Masterclass\Python-Narrative-Journey-master\11-Orange-Mission-Regular-Expressions-and-Reading-Files\Mission_Orange_Files\extracted_content\Five
#
#
# Sub-folders here are:
#
#
# files here are:
# 	AEITMYIRQLP.txt
# 	APJKSRITGGX.txt
# 	AQKATDFGXTS.txt
# 	ARLKFCWIAJE.txt
# 	AXJGVPVEFAS.txt
# 	BNUQEHCFRTG.txt
# 	BSKJDRNEZQM.txt
# 	BTYWAHLHKBM.txt
# 	BUGKBZWRRVI.txt
# 	BVBURZZCAPR.txt
# 	CAHBEVSVDDN.txt
# 	COMGMZBJAYE.txt
# 	CRFSDGYFSHA.txt
# 	CSCLFZCDYYC.txt
# 	CXBVCTRBBIE.txt
# 	DDLASODUVPX.txt
# 	DHZBAAYEADM.txt
# 	DQPZQLBCJYP.txt
# 	DYOPIIVMZOO.txt
# 	DZUWWXYIAEL.txt
# 	EAAOEPSAWMQ.txt
# 	EIPWXMQZJKU.txt
# 	ESIZWBHMGDP.txt
# 	ETCUEXWNBCF.txt
# 	EYTCGIOYWIW.txt
#
#
# Currently looking at folder: C:\Users\Sajakhta\Desktop\Complete_Python3_Masterclass\Python-Narrative-Journey-master\11-Orange-Mission-Regular-Expressions-and-Reading-Files\Mission_Orange_Files\extracted_content\Four
#
#
# Sub-folders here are:
#
#
# files here are:
# 	ECIOBYCDVFI.txt
# 	EMTGPSXQEJX.txt
# 	EPRNUHRSESC.txt
# 	ESDIZXHYCVY.txt
# 	EXVQSVBQQQH.txt
# 	QCTCKDIBBVG.txt
# 	QCWCFLKNZMN.txt
# 	QDDETWBHJYC.txt
# 	QTDYYIFPHAU.txt
# 	QVNJULGXNUM.txt
# 	REAXWSOIQDY.txt
# 	ROICPTWKXDX.txt
# 	RSXOTNGKBML.txt
# 	RXDARIDGKBF.txt
# 	RYNXFYXMKHG.txt
# 	TAKNAVDMZKV.txt
# 	THPNEGKTJWI.txt
# 	TJFMLJODVAD.txt
# 	TKCZSFQNJTX.txt
# 	TWUOYFCCYBQ.txt
# 	WFSKPTXPFCH.txt
# 	WHTOHQUWXIN.txt
# 	WNJISWPEBRS.txt
# 	WXDJDOGZEHN.txt
# 	WYDLGSGGXKV.txt
#
#
# Currently looking at folder: C:\Users\Sajakhta\Desktop\Complete_Python3_Masterclass\Python-Narrative-Journey-master\11-Orange-Mission-Regular-Expressions-and-Reading-Files\Mission_Orange_Files\extracted_content\One
#
#
# Sub-folders here are:
#
#
# files here are:
# 	HDOHZHFSTTK.txt
# 	HFUTPPAXDIS.txt
# 	HMNZTLIFGPD.txt
# 	HRQFTHKVJTL.txt
# 	HVUTZEVMSBW.txt
# 	JDLRVFCXYLU.txt
# 	JEHBLZPUPSP.txt
# 	JLTXKIGCWDL.txt
# 	JQUOBKFUACN.txt
# 	JTHSNBNPQSE.txt
# 	KCXGNQCZBLO.txt
# 	KFIUZFERLET.txt
# 	KMMLGJOWLGI.txt
# 	KNBSKDREHQU.txt
# 	KTXDHIOKAUI.txt
# 	LDGOCUQJNNS.txt
# 	LFEATJAAYDC.txt
# 	LHODFIKVTQA.txt
# 	LIFDHOFKWOI.txt
# 	LPNDVDXPZIG.txt
# 	PDJMSMNKIRM.txt
# 	PHWAVPEKAER.txt
# 	PLYCGPVEAWO.txt
# 	PQNVCVJINAR.txt
# 	PTOBBCJYURJ.txt
#
#
# Currently looking at folder: C:\Users\Sajakhta\Desktop\Complete_Python3_Masterclass\Python-Narrative-Journey-master\11-Orange-Mission-Regular-Expressions-and-Reading-Files\Mission_Orange_Files\extracted_content\Three
#
#
# Sub-folders here are:
#
#
# files here are:
# 	VAQIJTDOFUJ.txt
# 	VCFJCGJFBIH.txt
# 	VSXFSTABZDY.txt
# 	VVHFVZUNLOO.txt
# 	VVKGWLRMHLU.txt
# 	XAJMCPEWFNI.txt
# 	XFHJOTNPEJG.txt
# 	XHZPVUQTXIO.txt
# 	XJCWENFFGHB.txt
# 	XVMPVSVYKFR.txt
# 	YCESZHJDBXH.txt
# 	YDQFMWXOUMW.txt
# 	YQBIUHSUEVW.txt
# 	YQRNCMNFFHW.txt
# 	YYIZGBTQHZP.txt
# 	ZEZKKRBIZEB.txt
# 	ZKQJXAYKPVD.txt
# 	ZOWVXWPOGWP.txt
# 	ZXEZRQXZNPG.txt
# 	ZXIBJMPROKW.txt
#
#
# Currently looking at folder: C:\Users\Sajakhta\Desktop\Complete_Python3_Masterclass\Python-Narrative-Journey-master\11-Orange-Mission-Regular-Expressions-and-Reading-Files\Mission_Orange_Files\extracted_content\Two
#
#
# Sub-folders here are:
#
#
# files here are:
# 	GKQBQRCTNNK.txt
# 	GMMQQUBMJNR.txt
# 	GQTJJORZBXY.txt
# 	GTOTCIWMDBY.txt
# 	GXYSEPAFRTP.txt
# 	HARDNJGDRBC.txt
# 	HEORIXOTANT.txt
# 	HMUTDOVNYTV.txt
# 	HMZXPBOPRAE.txt
# 	HTOHSTYXTCO.txt
# 	LCJZYDHBFRM.txt
# 	LSQSTGPIGIY.txt
# 	LULTNYAQEJG.txt
# 	LVMBINRBJXL.txt
# 	LYZEQCVYNEZ.txt
# 	OHZOUOSFJQC.txt
# 	OIHMLGMWTHL.txt
# 	OKWFOOYTXFU.txt
# 	OMWIMVRCMYM.txt
# 	OYMAGXAGWHJ.txt
# 	SIKFPPLCJDN.txt
# 	SJMJLDGPBSJ.txt
# 	SOFUJYXTIMK.txt
# 	SPDZYGDHEWO.txt
# 	SWOFXREEHWA.txt
#
#
# Currently looking at folder: C:\Users\Sajakhta\Desktop\Complete_Python3_Masterclass\Python-Narrative-Journey-master\12-Yellow-Mission-Working-with-CSV-Files
#
#
# Sub-folders here are:
# 	.ipynb_checkpoints
# 	Yellow-Mission-Files
#
#
# files here are:
# 	00-Working-with-CSV-Files.ipynb
# 	01-Working-with-PDFs.ipynb
# 	02-Yellow-Mission-Overview.ipynb
# 	03-Yellow-Mission-Debrief.ipynb
# 	example.csv
# 	makeup_new.csv
# 	Some_New_Doc.pdf
# 	Some_new_file.pdf
# 	to_save_file.csv
# 	Working_Business_Proposal.pdf
#
#
# Currently looking at folder: C:\Users\Sajakhta\Desktop\Complete_Python3_Masterclass\Python-Narrative-Journey-master\12-Yellow-Mission-Working-with-CSV-Files\.ipynb_checkpoints
#
#
# Sub-folders here are:
#
#
# files here are:
# 	00-Working-with-CSV-Files-checkpoint.ipynb
# 	01-Working-with-PDFs-checkpoint.ipynb
# 	02-Yellow-Mission-Overview-checkpoint.ipynb
# 	03-Yellow-Mission-Debrief-checkpoint.ipynb
#
#
# Currently looking at folder: C:\Users\Sajakhta\Desktop\Complete_Python3_Masterclass\Python-Narrative-Journey-master\12-Yellow-Mission-Working-with-CSV-Files\Yellow-Mission-Files
#
#
# Sub-folders here are:
#
#
# files here are:
# 	Contact_Email_Information.pdf
# 	download_link.csv
#
#
# Currently looking at folder: C:\Users\Sajakhta\Desktop\Complete_Python3_Masterclass\Python-Narrative-Journey-master\13-Green-Mission-Sending-Emails-with-Python
#
#
# Sub-folders here are:
# 	.ipynb_checkpoints
#
#
# files here are:
# 	00-Overview-of-Sending-Emails.ipynb
# 	01-Overview-of-Received-Emails.ipynb
# 	02-Overview-of-Green-Mission.ipynb
# 	03-Green-Mission-Debrief.ipynb
#
#
# Currently looking at folder: C:\Users\Sajakhta\Desktop\Complete_Python3_Masterclass\Python-Narrative-Journey-master\13-Green-Mission-Sending-Emails-with-Python\.ipynb_checkpoints
#
#
# Sub-folders here are:
#
#
# files here are:
# 	00-Overview-of-Sending-Emails-checkpoint.ipynb
# 	01-Overview-of-Received-Emails-checkpoint.ipynb
# 	02-Overview-of-Green-Mission-checkpoint.ipynb
# 	03-Green-Mission-Debrief-checkpoint.ipynb
#
#
# Currently looking at folder: C:\Users\Sajakhta\Desktop\Complete_Python3_Masterclass\Python-Narrative-Journey-master\14-Blue-Mission-Working-with-Images-with-Python
#
#
# Sub-folders here are:
# 	.ipynb_checkpoints
# 	Blue_Mission_Files
#
#
# files here are:
# 	00-Overview-of-Working-with-Images.ipynb
# 	01-Blue-Mission-Overview.ipynb
# 	02-Blue-Mission-Debrief.ipynb
# 	blue_color.png
# 	example.jpg
# 	pencils.jpg
# 	red_color.jpg
#
#
# Currently looking at folder: C:\Users\Sajakhta\Desktop\Complete_Python3_Masterclass\Python-Narrative-Journey-master\14-Blue-Mission-Working-with-Images-with-Python\.ipynb_checkpoints
#
#
# Sub-folders here are:
#
#
# files here are:
# 	00-Overview-of-Working-with-Images-checkpoint.ipynb
# 	01-Blue-Mission-Overview-checkpoint.ipynb
# 	02-Blue-Mission-Debrief-checkpoint.ipynb
#
#
# Currently looking at folder: C:\Users\Sajakhta\Desktop\Complete_Python3_Masterclass\Python-Narrative-Journey-master\14-Blue-Mission-Working-with-Images-with-Python\Blue_Mission_Files
#
#
# Sub-folders here are:
#
#
# files here are:
# 	cover_image.PNG
# 	image_link.PNG
#
#
# Currently looking at folder: C:\Users\Sajakhta\Desktop\Complete_Python3_Masterclass\Python-Narrative-Journey-master\15-Indigo-Mission-Decryption-with-Python
#
#
# Sub-folders here are:
# 	.ipynb_checkpoints
#
#
# files here are:
# 	00-Encryption-and-Hashing-with-Python.ipynb
# 	01-Indigo-Mission-Overview.ipynb
# 	02-Indigo-Mission-Debrief.ipynb
#
#
# Currently looking at folder: C:\Users\Sajakhta\Desktop\Complete_Python3_Masterclass\Python-Narrative-Journey-master\15-Indigo-Mission-Decryption-with-Python\.ipynb_checkpoints
#
#
# Sub-folders here are:
#
#
# files here are:
# 	00-Encryption-and-Hashing-with-Python-checkpoint.ipynb
# 	01-Indigo-Mission-Overview-checkpoint.ipynb
# 	02-Indigo-Mission-Debrief-checkpoint.ipynb
#
#
# Currently looking at folder: C:\Users\Sajakhta\Desktop\Complete_Python3_Masterclass\Python-Narrative-Journey-master\16-Violet-Mission-Mapping-with-Python
#
#
# Sub-folders here are:
# 	.ipynb_checkpoints
# 	Violet_Mission_Folders
#
#
# files here are:
# 	00-Geographical-Mapping-with-Python.ipynb
# 	01-Violet-Mission-Overview.ipynb
# 	02-Violet-Mission-Debrief.ipynb
# 	countries.csv
# 	gmap_plot.html
# 	message_lats_longs.csv
# 	message_new_pen.txt
# 	my_example_gmap_plot.html
#
#
# Currently looking at folder: C:\Users\Sajakhta\Desktop\Complete_Python3_Masterclass\Python-Narrative-Journey-master\16-Violet-Mission-Mapping-with-Python\.ipynb_checkpoints
#
#
# Sub-folders here are:
#
#
# files here are:
# 	00-Geographical-Mapping-with-Python-checkpoint.ipynb
# 	01-Purple-Mission-Overview-checkpoint.ipynb
# 	01-Violet-Mission-Overview-checkpoint.ipynb
# 	02-Purple-Mission-Debrief-checkpoint.ipynb
# 	02-Violet-Mission-Debrief-checkpoint.ipynb
#
#
# Currently looking at folder: C:\Users\Sajakhta\Desktop\Complete_Python3_Masterclass\Python-Narrative-Journey-master\16-Violet-Mission-Mapping-with-Python\Violet_Mission_Folders
#
#
# Sub-folders here are:
#
#
# files here are:
# 	gmap_plot.html
# 	map.png
#
#
# Currently looking at folder: C:\Users\Sajakhta\Desktop\Complete_Python3_Masterclass\__pycache__
#
#
# Sub-folders here are:
#
#
# files here are:
# 	mymodule.cpython-37.pyc
# 	one.cpython-37.pyc
